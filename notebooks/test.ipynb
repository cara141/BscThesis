# %%
from backend.FeatureExtractor import FeatureExtractor
from backend.MusicGenreClassifier import MusicGenreClassifier

extractor = FeatureExtractor()
classifier = MusicGenreClassifier()
# Out:
# Model loaded from ../models/Router\Router_model
# Model loaded from ../models/Classical\Classical_model
# Model loaded from ../models/Electronic\Electronic_model
# Model loaded from ../models/Experimental\Experimental_model
# Model loaded from ../models/Folk\Folk_model
# Model loaded from ../models/Hip-Hop\Hip-Hop_model
# Model loaded from ../models/Instrumental\Instrumental_model
# Model loaded from ../models/International\International_model
# Model loaded from ../models/Jazz\Jazz_model
# Model loaded from ../models/Pop\Pop_model
# Model loaded from ../models/Rock\Rock_model

# %%
f = open("../test.mp3", "rb")
data = f.read()
feature_vec = extractor.extract_from_bytes(data)

# %%
print(len(feature_vec))
# Out:
# 518

# %%
prediction = classifier.predict(feature_vec)
print(prediction)
# Out:
# Experimental
